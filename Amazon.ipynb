# %%
from pprint import pprint
import time
import random
import string

# %%
shopping = False
command = ""
cart = []

# %%
class Login:
    def first(self):
        while True:
            password = int(input("Enter the password:"))
            if password == 12345:
                print("password verified")
                time.sleep(2)
                print("Opening Amazon service")
                time.sleep(2)
                break
            else:
                print("Wrong Password,Try again")
l1 = Login()
l1.first()
# Out:
# Enter the password:1234
# Wrong Password,Try again
# Enter the password:12345
# password verified
# Opening Amazon service

# %%
class Amazon:
    def items(self):
        print("""\t\t\t\t\t\t\tWELCOME TO AMAZON ONLINE SHOPPING PORTAL\n\t\t\t\t\t\t\t\t\t Our Products\n\n\tphone : RS.10000\tlaptop : RS.25000\tTV : RS.30000\tHead phone : RS.400\tComputer : RS.55000\t\n\n\tKeyboard : Rs.1000\tMouse : Rs.100\tHarddisk : Rs.1500\tFridge : Rs.15000\tWashing Machine : Rs.25000\n\n\n\n""")
amz = Amazon()
amz.items()
# Out:
# 							WELCOME TO AMAZON ONLINE SHOPPING PORTAL
# 									 Our Products
#
# 	phone : RS.10000	laptop : RS.25000	TV : RS.30000	Head phone : RS.400	Computer : RS.55000
#
# 	Keyboard : Rs.1000	Mouse : Rs.100	Harddisk : Rs.1500	Fridge : Rs.15000	Washing Machine : Rs.25000

# %%
class Amazon:
    def shopping(self):
        amount = 0
        while True:
            command = input("\n>>>")
            if command == "phone":
                print("You selected phone")
                time.sleep(1)
                print("Phone-10000")
                quantity = int(input("How Many: "))
                time.sleep(1)
                print(f"You ordered {quantity} phone")
                time.sleep(1)
                phone = (f"phone- {quantity}- {quantity*10000} ")
                cart.append(phone)
                amount += quantity*10000
                print("phone is added to Cart")
                shopping = True
            if command == "rphone":
                for items in cart:
                    if items == phone:
                        cart.remove(phone)
                        amount -= quantity*10000
                        print("Phone is removed form the cart")

            if command == "laptop":
                time.sleep(1)
                print("You selected laptop")
                time.sleep(1)
                print("Laptop-25000")
                quantity = int(input("How Many: "))
                time.sleep(1)
                print(f"You ordered {quantity} laptop")
                laptop = (f"laptop- {quantity}- {quantity*25000} ")
                cart.append(laptop)
                amount += quantity*25000
                print("laptop is added to Cart")
                shopping = True
            if command == "rlaptop":
                for items in cart:
                    if items == laptop:
                        cart.remove(laptop)
                        amount -= quantity*25000
                        print("Laptop is removed form the cart")

            if command == "tv":
                print("You selected Tv")
                time.sleep(1)
                print("TV-30000")
                quantity = int(input("How Many: "))
                time.sleep(1)
                print(f"You ordered {quantity} Tv")
                Tv = (f"Tv- {quantity}- {quantity*30000} ")
                cart.append(Tv)
                amount += quantity*30000
                print("Tv is added to Cart")
                shopping = True
            if command == "rtv":
                for items in cart:
                    if items == Tv:
                        cart.remove(Tv)
                        amount -= quantity*30000
                        print("Tv is removed form the cart")

            if command == "head phone":
                print("You selected Head Phone")
                time.sleep(1)
                print("Head Phone-400")
                quantity = int(input("How Many: "))
                time.sleep(1)
                print(f"You ordered {quantity} Head phone")
                time.sleep(1)
                Head_phone = (f"Head phone- {quantity}- {quantity*400} ")
                cart.append(Head_phone)
                amount += quantity*400
                print("Head Phone  is added to Cart")
                shopping = True
            if command == "rhead phone":
                for items in cart:
                    if items == Head_phone:
                        cart.remove(Head_phone)
                        amount -= quantity*400
                        print("Head Phone is removed form the cart")

            if command == "computer":
                print("You selected Computer")
                time.sleep(1)
                print("Computer-55000")
                quantity = int(input("How Many: "))
                time.sleep(1)
                print(f"You ordered {quantity} Computer")
                time.sleep(1)
                computer = (f"Computer- {quantity}- {quantity*55000} ")
                cart.append(computer)
                amount += quantity*55000
                print("Computer is added to Cart")
                shopping = True
            if command == "rcomputer":
                for items in cart:
                    if items == computer:
                        cart.remove(computer)
                        amount -= quantity*55000
                        print("Computer is removed form the cart")
            if command == "keyboard":
                print("You selected keyboard")
                time.sleep(1)
                print("Keyboard-1000")
                quantity = int(input("How Many: "))
                time.sleep(1)
                print(f"You ordered {quantity} keyboard")
                time.sleep(1)
                keyboard = (f"keyboard- {quantity}- {quantity*1000} ")
                cart.append(keyboard)
                amount += quantity*10000
                print("keyboard is added to Cart")
                shopping = True
            if command == "rkeyboard":
                for items in cart:
                    if items == keyboard:
                        cart.remove(keyboard)
                        amount -= quantity*1000
                        print("keyboard is removed form the cart")
            if command == "mouse":
                print("You selected mouse")
                time.sleep(1)
                print("Mouse-100")
                quantity = int(input("How Many: "))
                time.sleep(1)
                print(f"You ordered {quantity} mouse")
                time.sleep(1)
                mouse = (f"mouse- {quantity}- {quantity*100} ")
                cart.append(mouse)
                amount += quantity*100
                print("mouse is added to Cart")
                shopping = True
            if command == "rmouse":
                for items in cart:
                    if items == mouse:
                        cart.remove(mouse)
                        amount -= quantity*100
                        print("mouse is removed form the cart")
            if command == "harddisk":
                print("You selected Harddisk")
                time.sleep(1)
                print("Harddisk-1500")
                quantity = int(input("How Many: "))
                time.sleep(1)
                print(f"You ordered {quantity} Harddisk")
                time.sleep(1)
                Harddisk = (f"Harddisk- {quantity}- {quantity*1500} ")
                cart.append(Harddisk)
                amount += quantity*1500
                print("Harddisk is added to Cart")
                shopping = True
            if command == "rHarddisk":
                for items in cart:
                    if items == Harddisk:
                        cart.remove(Harddisk)
                        amount -= quantity*1500
                        print("Harddisk is removed form the cart")
            if command == "fridge":
                print("You selected Fridge")
                time.sleep(1)
                print("Fridge-15000")
                quantity = int(input("How Many: "))
                time.sleep(1)
                print(f"You ordered {quantity} Fridge")
                time.sleep(1)
                fridge = (f"Fridge- {quantity}- {quantity*15000} ")
                cart.append(fridge)
                amount += quantity*15000
                print("fridge is added to Cart")
                shopping = True
            if command == "rfridge":
                for items in cart:
                    if items == fridge:
                        cart.remove(fridge)
                        amount -= quantity*15000
                        print("Fridge is removed form the cart")
            if command == "washing machine":
                print("You selected Washing Machine")
                time.sleep(1)
                print("Washing Machine-15000")
                quantity = int(input("How Many: "))
                time.sleep(1)
                print(f"You ordered {quantity} Washing Machine")
                time.sleep(1)
                washing_machine = (
                    f"washing machine- {quantity}- {quantity*15000} ")
                cart.append(washing_machine)
                amount += quantity*15000
                print("Washing Machine is added to Cart")
                shopping = True
            if command == "rwashing machine":
                for items in cart:
                    if items == washing_machine:
                        cart.remove(washing_machine)
                        amount -= quantity*15000
                        print("Washing Machine is removed form the cart")
            if command == "bill":
                if shopping == True:
                    for dinesh in cart:
                        print(dinesh)
                else:
                    print("Choose Items First !")
                    break
                print(f"Total = {amount} rupees only")
            if command == "cart":
                time.sleep(1)
                print(cart)
                time.sleep(1)
            if command == "order":
                cap = "".join(random.choices(string.ascii_lowercase +
                              string.ascii_uppercase+string.digits, k=4))
                print(cap)
                time.sleep(1)
                captcha = input("Enter the Above Captcha to confirm order:")
                if captcha == cap:
                    time.sleep(2)
                    print("Captcha Verified Successfully")
                else:
                    time.sleep(1)
                    print("Wrong Captcha")
                    time.sleep(2)
                    break
                time.sleep(1)
                print("Items Preview\n\n", cart)
                if cart == []:
                    time.sleep(1)
                    print("Shop First")
                    break
                else:
                    name = input("Enter your Name: ")
                    email = input("Enter your Email:")
                    address = input("Enter your Address: ")
                    landmark = input("Enter the landmrak:")
                    Mobile_number = int(input("Mobile Number: "))
                    OTP = random.randrange(1000, 10000)
                    time.sleep(1)
                    print(OTP)
                    time.sleep(2)
                    OneTimePassword = int(input("Enter the OTP: "))
                if OneTimePassword == OTP:
                    print("OTP Verified")
                    time.sleep(1)
                    print("COD or Online pay")
                else:
                    print(
                        "Wrong OTP,please enter the OTP Correctly for process your order")
                    time.sleep(1)
                    print(":( Try Again")
                    time.sleep(2)
                    break
            if command == "cod":
                print(
                    f"Billing Address:\n______________________________\n{name},\n{email},\n{address},\n{landmark},\n{Mobile_number}.\n______________________________")
                est = random.randrange(1, 31)
                est1 = random.randrange(1, 12)
                estimated_delivery = ""
                print(f"Product will delivered by {est}-{est1}-2022")
                time.sleep(1)
                print(f"Make payment of {amount} rupees on the delivery")
                time.sleep(1)
                print("Thank You")
                time.sleep(1)
                print("Visit Again ")
                time.sleep(1)
                print("""\n\t\t\t\t\t Our Products\n\n\tphone : RS.10000\tlaptop : RS.25000\tTV : RS.30000\tHead phone : RS.400\tComputer : RS.55000\t\n\n\tKeyboard : Rs.1000\tMouse : Rs.100\tHarddisk : Rs.1500\tFridge : Rs.15000\tWashing Machine : Rs.25000\n\n\n\n""")
                if estimated_delivery == est:
                    pass
                break
            if command == "online pay":
                print(
                    f"Billing Address:\n_______________________________\n{name},\n{email},\n{address},\n{landmark},\n{Mobile_number}.\n______________________________")
                time.sleep(1)
                est = random.randrange(1, 31)
                est1 = random.randrange(1, 12)
                estimated_delivery = ""
                print(f"Product will delivered by {est}-{est1}-2022")
                time.sleep(1)
                print(f"bill amount {amount} paid successfully")
                time.sleep(1)
                print("Thank You")
                time.sleep(1)
                print("Visit Again ")
                time.sleep(1)
                print("""\n\t\t\t\t\t Our Products\n\n\tphone : RS.10000\tlaptop : RS.25000\tTV : RS.30000\tHead phone : RS.400\tComputer : RS.55000\t\n\n\tKeyboard : Rs.1000\tMouse : Rs.100\tHarddisk : Rs.1500\tFridge : Rs.15000\tWashing Machine : Rs.25000\n\n\n\n""")
                if estimated_delivery == est:
                    pass
                break
            if command == "end":
                break
amz = Amazon()
amz.shopping()
# Out:
# >>>laptop
# You selected laptop
# Laptop-25000
# How Many: 2
# You ordered 2 laptop
# laptop is added to Cart
#
# >>>computer
# You selected Computer
# Computer-55000
# How Many: 2
# You ordered 2 Computer
# Computer is added to Cart
#
# >>>phone
# You selected phone
# Phone-10000
# How Many: 5
# You ordered 5 phone
# phone is added to Cart
#
# >>>cart
# ['laptop- 2- 50000 ', 'Computer- 2- 110000 ', 'phone- 5- 50000 ']
#
# >>>rcomputer
# Computer is removed form the cart
#
# >>>cart
# ['laptop- 2- 50000 ', 'phone- 5- 50000 ']
#
# >>>bill
# laptop- 2- 50000
# phone- 5- 50000
# Total = -65000 rupees only
#
# >>>order
# AiLL
# Enter the Above Captcha to confirm order:AiLL
# Captcha Verified Successfully
# Items Preview
#
#  ['laptop- 2- 50000 ', 'phone- 5- 50000 ']
# Enter your Name: XYZ
# Enter your Email:XYZ@gmail.com
# Enter your Address: Big street
# Enter the landmrak:near shopping mall
# Mobile Number: 1234567891
# 5573
# Enter the OTP: 5573
# OTP Verified
# COD or Online pay
#
# ...
